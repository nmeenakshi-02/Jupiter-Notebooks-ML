# %% [markdown]
# # This is Hands on session of Feature Engieerig in Machine Learning

# %% [markdown]
# dataset link : https://www.kaggle.com/datasets/huyngohoang/housingcsv

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('Housing.csv')
df=df.select_dtypes(include=np.number)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
#perform Absolute maximum scaling
max_abs=np.max(np.abs(df), axis=0)#
scaled_df=df/max_abs
scaled_df.max
# Out:
# <bound method DataFrame.max of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      -0.982951  0.902980            0.788462     0.022380        0.020016
# 1      -0.982871  0.902503            0.403846     0.180544        0.171606
# 2      -0.983032  0.902265            1.000000     0.037309        0.029480
# 3      -0.983112  0.902265            1.000000     0.032401        0.036462
# 4      -0.983112  0.902265            1.000000     0.041378        0.043445
# ...          ...       ...                 ...          ...             ...
# 20635  -0.973784  0.941120            0.480769     0.042345        0.058029
# 20636  -0.974749  0.941359            0.346154     0.017726        0.023274
# 20637  -0.974829  0.939928            0.326923     0.057325        0.075252
# 20638  -0.975633  0.939928            0.346154     0.047304        0.063460
# 20639  -0.974990  0.938498            0.307692     0.070829        0.095578
#
# ...

# %%
#perform standalization
from sklearn.preprocessing import StandardScaler
scaler=Standardscaler()
scaled_df=scaled.fit_transform(df)
x=pd.DataFrame(scaled_df)

# %%
#perform normalization
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
Scaler.fit_transform(df)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
from sklearn.preprocessing import RobustScaler
Scaler=RobustScaler()
Scaler_data=Scaler.fit_transform(df)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...
